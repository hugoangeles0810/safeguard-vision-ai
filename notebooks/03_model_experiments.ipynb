# %% [markdown]
# # Model Experiments
#
# This notebook contains experiments with different model architectures.
#
# ## Goals:
# 1. Train LSTM baseline
# 2. Experiment with LSTM variants (BiLSTM, GRU)
# 3. Train Transformer model
# 4. Compare architectures
# 5. Hyperparameter tuning
# 6. Select best model

# %%
import sys
sys.path.append('..')

import torch
import numpy as np
import matplotlib.pyplot as plt
import yaml
from pathlib import Path

from src.data.dataset import FallDetectionDataset
from src.data.dataloader import create_dataloaders
from src.models.lstm import LSTMFallDetector
from src.models.transformer import TransformerFallDetector
from src.training.trainer import Trainer
from src.training.losses import get_loss_function
from src.training.metrics import compute_metrics, print_metrics

# %% [markdown]
# ## 1. Load Configuration

# %%
# TODO: Load config from YAML
# config_path = '../configs/lstm_baseline.yaml'

# %% [markdown]
# ## 2. Prepare Data

# %%
# TODO: Create dataloaders
# train_loader, val_loader, test_loader = create_dataloaders(config)

# %% [markdown]
# ## 3. LSTM Baseline

# %%
# TODO: Initialize LSTM model
# TODO: Train
# TODO: Evaluate

# %% [markdown]
# ## 4. Transformer Model

# %%
# TODO: Initialize Transformer model
# TODO: Train
# TODO: Evaluate

# %% [markdown]
# ## 5. Model Comparison

# %%
# TODO: Create comparison table
# Compare: accuracy, precision, recall, F1, AUC
# Compare: training time, inference speed
# Compare: number of parameters

# %% [markdown]
# ## 6. Hyperparameter Tuning

# %%
# TODO: Grid search or random search
# Tune: learning rate, hidden size, num layers, dropout
