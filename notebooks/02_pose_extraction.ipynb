# %% [markdown]
# # Pose Extraction Experiments
#
# This notebook compares MediaPipe and YOLOv8-Pose for keypoint extraction.
#
# ## Goals:
# 1. Test MediaPipe Pose on sample videos
# 2. Test YOLOv8-Pose on same videos
# 3. Compare accuracy, speed, and robustness
# 4. Select best approach for the project
# 5. Process entire dataset with chosen method

# %%
import sys
if not IN_COLAB:
    sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
import cv2
from pathlib import Path
import time

from src.pose.mediapipe_extractor import MediaPipeExtractor
from src.pose.yolo_extractor import YOLOv8Extractor

# %%
if IN_COLAB:
    # Mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')
    
    # Clone repository
    import os
    if not os.path.exists('/content/safeguard-vision-ai'):
        # !git clone https://github.com/hugoangeles0810/safeguard-vision-ai.git
        os.chdir('/content/safeguard-vision-ai')
        
        # Install dependencies
        # !pip install -q -r requirements.txt
    else:
        os.chdir('/content/safeguard-vision-ai')
    
    # Setup Google Drive paths
    import sys
    sys.path.insert(0, '/content/safeguard-vision-ai/src')
    from utils.drive_utils import setup_paths
    paths = setup_paths(project_name='safeguard-vision-ai')
    
    print("\n✓ Google Drive integration configured")
else:
    # Local paths
    from pathlib import Path
    project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
    paths = {
        'project_root': project_root,
        'data_raw': project_root / 'data' / 'raw',
        'data_processed': project_root / 'data' / 'processed',
    }
    print("✓ Using local paths")

# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
import cv2
from pathlib import Path
import time

from src.pose.mediapipe_extractor import MediaPipeExtractor
from src.pose.yolo_extractor import YOLOv8Extractor

# %% [markdown]
# ## 1. MediaPipe Pose Extraction

# %%
# TODO: Initialize MediaPipe
# TODO: Extract poses from sample videos
# TODO: Measure FPS and accuracy

# %% [markdown]
# ## 2. YOLOv8-Pose Extraction

# %%
# TODO: Initialize YOLOv8-Pose
# TODO: Extract poses from same videos
# TODO: Measure FPS and accuracy

# %% [markdown]
# ## 3. Comparison

# %%
# TODO: Compare results side-by-side
# Create comparison table:
# - Speed (FPS)
# - Accuracy (qualitative)
# - Robustness to occlusions
# - Ease of use

# %% [markdown]
# ## 4. Batch Processing

# %%
# TODO: Process entire dataset with chosen method
# Save keypoints to data/processed/
